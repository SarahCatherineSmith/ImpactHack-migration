# %%
# Hacking together the Bubble Plot Datasets

import pandas as pd
import numpy as np

# %%
country_of_origin_csv_df = pd.read_csv("Asylum_Country_Origin_00_17.csv")

# %%
country_of_origin_csv_df.head()
# Out:
#      yr_2007  cartodb_id                  name            country_or  \
# 0  3609746.0           1           Afghanistan           Afghanistan
# 1   198970.0           2                Angola                Angola
# 2    16982.0           3               Albania               Albania
# 3       12.0           4               Andorra               Andorra
# 4      318.0           5  United Arab Emirates  United Arab Emirates
#
#      yr_2000    yr_2001    yr_2002    yr_2003    yr_2004    yr_2005  \
# 0  4778785.0  5166652.0  6013458.0  3174558.0  3598240.0  3192177.0
# 1   705464.0   695600.0   736745.0   474278.0   328645.0   277950.0
# 2     9620.0    11604.0    15756.0    14920.0    13806.0    15301.0
# 3        3.0        8.0       13.0       13.0        7.0       12.0
# 4       25.0       49.0       69.0       45.0       82.0       46.0
#
#      ...        yr_2008    yr_2009    yr_2010    yr_2011    yr_2012  \
# 0    ...      3374020.0  3280950.0  4404457.0  4250315.0  4132670.0
# ...

# %%
country_pop_df = pd.read_csv("Pop_90_17.csv", encoding="ISO-8859-1")

# %%
country_pop_df.head()
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0                NaN                          NaN                NaN
# 1  Last Updated Date                      9/21/18                NaN
# 2                NaN                          NaN                NaN
# 3       Country Name                 Country Code     Indicator Name
# 4              Aruba                          ABW  Population, total
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3  Indicator Code      1990.0      1991.0      1992.0      1993.0      1994.0
# 4     SP.POP.TOTL     62149.0     64622.0     68235.0     72504.0     76700.0
#
#    Unnamed: 9     ...       Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# ...

# %%
Pol_Stab_df = pd.read_csv("PoliticalStabilityNoViolence.csv", encoding="ISO-8859-1")

# %%
Pol_Stab_df.head()
# Out:
#   Political Stability and Absence of Violence/Terrorism  \
# 0  Political Stability and Absence of Violence/Te...
# 1                                                NaN
# 2                                             Legend
# 3                                           Estimate
# 4                                             StdErr
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Estimate of governance (ranges from approximat...        NaN        NaN
# 4  Standard error reflects variability around the...        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# ...
