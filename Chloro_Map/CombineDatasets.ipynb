# %%
import pandas as pd
import csv

# %%
drought = pd.read_csv('../Datasets/Drought_2014.csv')

# %%
dat = []
with open('Chloropleth_Asylum_Data.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='"')
    for row in spamreader:
        dat.append(row)
        
asylum = pd.DataFrame(data=dat[1:], columns=dat[0])

# %%
asylum = pd.DataFrame(data=dat[1:], columns=dat[0])

# %%
coo = pd.read_csv('coo_cod.csv')
# Out:
# C:\Users\Ryan Abrahams\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (3,4,5,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
coo.columns
# Out:
# Index(['Year', 'Origin', 'Country / territory of asylum/residence',
#        'Refugees (incl. refugee-like situations)',
#        'Asylum-seekers (pending cases)', 'Returned refugees',
#        'Internally displaced persons (IDPs)', 'Returned IDPs',
#        'Stateless persons', 'Others of concern', 'Total Population'],
#       dtype='object')

# %%
coo
# Out:
#        Year       Origin Country / territory of asylum/residence  \
# 0      1990  Afghanistan                                Pakistan
# 1      1990  Afghanistan                  Iran (Islamic Rep. of)
# 2      1990  Afghanistan                                   India
# 3      1990  Afghanistan                United States of America
# 4      1990  Afghanistan                                   Italy
# 5      1990  Afghanistan                                  Sweden
# 6      1990  Afghanistan                                 Lebanon
# 7      1990  Afghanistan                          United Kingdom
# 8      1990  Afghanistan                                 Denmark
# 9      1990  Afghanistan                                   China
# 10     1990  Afghanistan                                   Nepal
# 11     1990      Albania   Serbia and Kosovo (S/RES/1244 (1999))
# 12     1990      Albania                                   Italy
# ...
